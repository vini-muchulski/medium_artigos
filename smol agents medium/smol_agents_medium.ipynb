# %%
# !pip install -U smolagents smolagents[litellm] langchain-community langchain  -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.5/90.5 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 464.1/464.1 kB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.7/412.7 kB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 20.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 28.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 918.4 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.6/460.6 kB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 43.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.

# %%
from smolagents import tool, LiteLLMModel ,DuckDuckGoSearchTool
from smolagents.agents import ToolCallingAgent
from google.colab import userdata
import os
from typing import Optional
#TOKEN =  userdata.get('OPENAI_API_KEY')
TOKEN =  userdata.get('GEMINI_API_KEY')

model = LiteLLMModel(model_id="gemini/gemini-2.0-flash-exp",api_key=TOKEN)

#web_agent
agent = ToolCallingAgent(tools=[DuckDuckGoSearchTool()], model=model)

agent.run("Search on the web about UFSC. Write a small paragraph about it in portuguese")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search on the web about UFSC. Write a small paragraph about it in portuguese                                    │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-2.0-flash-exp ────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'web_search' with arguments: {'query': 'UFSC'}                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: ## Search Results
#
# |UFSC](https://ufsc.br/)
# A Pró-Reitoria de Extensão da UFSC seleciona, de 18 a 24 de janeiro, estudantes de graduação para participar da
# Operação Amazonas do Projeto Rondon. As informações sobre |…] Manutenção na rede elétrica da UFSC envolve mais de
# 60 subestações em Florianópolis
#
# |Universidade Federal de Santa Catarina - UFSC](https://ufsc.br/a-ufsc/)
# A UFSC é uma instituição pública de ensino superior que oferece cursos de graduação, pós-graduação, pesquisa e
# extensão em cinco campi no estado de Santa Catarina. Saiba mais sobre sua história, missão, valores e atuação na
# região.
#
# |Federal University of Santa Catarina -
# Wikipedia](https://en.wikipedia.org/wiki/Federal_University_of_Santa_Catarina)
# UFSC is a public university in Florianópolis, Brazil, ranked among the best in Latin America and the country. It
# offers 119 undergraduate programs, 82 master's and 55 doctoral degrees, and has four campuses in the state of Santa
# Catarina.
#
# |Universidade Federal de Santa Catarina](https://en.ufsc.br/?s)
# UFSC achieved a final score of 76.6 (on a scale |…] News. UFSC has 41 researchers ranked among the most influential
# in the world. 25/09/2024 12:34. The Universidade Federal de Santa Catarina (UFSC) has 41 researchers ranked among
# the top-cited scientists in the world, according to the publishing company Elsevier. The database, developed ...
#
# |Vestibular Unificado UFSC/IFSC/IFC 2025](https://vestibularunificado2025.ufsc.br/)
# DESTAQUES: As vagas remanescentes para ingresso no 1 o semestre de 2025 nos cursos da UFSC serão ofertadas no
# Processo Seletivo por Histórico Escolar 2025-1, com inscrições gratuitas no período de 30/01 a 05/02/2025.;
# Acompanhe as chamadas de candidatos realizadas por cada instituição participante do Vestibular Unificado.
#
# |Universidade Federal de Santa Catarina - en.ufsc.br](https://en.ufsc.br/2022/06/)
# The Universidade Federal de Santa Catarina (UFSC) is ranked 23rd among the best universities in Latin America,
# according to the QS World University Rankings 2023. The survey places UFSC among the thousand best universities in
# the world, in the 801-1000 band, the same as in the previous edition. The ranking is prepared annually by
# Quacquarelli ...
#
# |Universidade Federal de Santa Catarina](https://en.ufsc.br/structure/schools-and-departments/)
# E-mail: gr@contato.ufsc.br Website: gabinete.ufsc.br UFSC mailing address: Campus Universitário Reitor João David
# Ferreira Lima Trindade - Florianópolis - SC CEP: 88040-900 Telephone: +55 48 3721-900. Follow UFSC on social media:
# Desenvolvido com o CMS de código aberto Wordpress;
#
# |Seleção UFSC/SiSU 2025](https://sisu2025.ufsc.br/)
# As matrículas dos candidatos classificados na chamada regular do SiSU-UFSC 2025 devem ser realizadas no período de
# 30/01 a 03/02/2025. Para mais informações, clique aqui. ↓ ↓ ↓ Últimas Atualizações ↓ ↓ ↓ ...
#
# |Seleção UFSC/SiSU 2025](https://sisu2025.ufsc.br/guia-de-cursos/)
# UFSC/IFSC/IFC 2025. Contatos. Endereço: Universidade Federal de Santa Catarina Comissão Permanente do Vestibular -
# COPERVE Campus Universitário Reitor João David Ferreira Lima - Trindade Florianópolis-SC CEP: 88040-900 Horário de
# Atendimento: Presencial: das 07h às 19h
#
# |Pró-Reitoria de Graduação e Educação Básica - UFSC](https://prograd.ufsc.br/cursos-de-graduacao-da-ufsc/)
# prograd@contato.ufsc.br Horário de Funcionamento da Coordenadoria de Apoio Administrativo: Segunda a sexta-feira,
# das 8h às 12h e das 13:30h às 17:30h. Desenvolvido com o CMS de código aberto Wordpress; Última atualização do site
# foi em 31 de janeiro 2025 - 12:18:28 ...
# [Step 0: Duration 1.63 seconds| Input tokens: 1,073 | Output tokens: 6]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'final_answer' with arguments: {'answer': 'A Universidade Federal de Santa Catarina (UFSC) é uma  │
# │ instituição pública de ensino superior localizada em Florianópolis, Brasil. Ela se destaca como uma das         │
# │ melhores universidades da América Latina e do país, oferecendo cursos de graduação, pós-graduação, pesquisa e   │
# │ extensão em seus cinco campi no estado de Santa Catarina. A UFSC também possui diversos pesquisadores           │
# │ reconhecidos entre os mais influentes do mundo e está bem posicionada em rankings universitários                │
# │ internacionais, como o QS World University Rankings.'}                                                          │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Final answer: A Universidade Federal de Santa Catarina (UFSC) é uma instituição pública de ensino superior
# localizada em Florianópolis, Brasil. Ela se destaca como uma das melhores universidades da América Latina e do
# país, oferecendo cursos de graduação, pós-graduação, pesquisa e extensão em seus cinco campi no estado de Santa
# Catarina. A UFSC também possui diversos pesquisadores reconhecidos entre os mais influentes do mundo e está bem
# posicionada em rankings universitários internacionais, como o QS World University Rankings.
# [Step 1: Duration 1.67 seconds| Input tokens: 3,325 | Output tokens: 110]
# 'A Universidade Federal de Santa Catarina (UFSC) é uma instituição pública de ensino superior localizada em Florianópolis, Brasil. Ela se destaca como uma das melhores universidades da América Latina e do país, oferecendo cursos de graduação, pós-graduação, pesquisa e extensão em seus cinco campi no estado de Santa Catarina. A UFSC também possui diversos pesquisadores reconhecidos entre os mais influentes do mundo e está bem posicionada em rankings universitários internacionais, como o QS World University Rankings.'

# %%
@tool
def get_weather(location: str, celsius: Optional[bool] = False) -> str:
   """
   Obtém a previsão do tempo para os próximos dias no local especificado.
   Secretamente esta ferramenta não se importa com o local, ela odeia o clima em todos os lugares.

   Args:
       location: o local
       celsius: a temperatura

   Returns:
       str: A previsão do tempo
   """
   return f"O clima em {location} está ensolarado e com temperaturas acima de 30°C"

agent = ToolCallingAgent(tools=[get_weather], model=model)

print(agent.run("Qual é o tempo em São PAULO?"))
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Qual é o tempo em São PAULO?                                                                                    │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-2.0-flash-exp ────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'get_weather' with arguments: {'location': 'São PAULO'}                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: O clima em São PAULO está ensolarado e com temperaturas acima de 30°C
# [Step 0: Duration 0.72 seconds| Input tokens: 1,111 | Output tokens: 7]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'final_answer' with arguments: {'answer': 'O clima em São PAULO está ensolarado e com             │
# │ temperaturas acima de 30°C'}                                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Final answer: O clima em São PAULO está ensolarado e com temperaturas acima de 30°C
# [Step 1: Duration 0.82 seconds| Input tokens: 2,350 | Output tokens: 31]
# O clima em São PAULO está ensolarado e com temperaturas acima de 30°C

# %%
from smolagents import CodeAgent

agent = CodeAgent(tools=[], model=model, additional_authorized_imports=["yfinance","pandas","matplotlib.pyplot"])

agent.run("Fetch the NVIDIA stock price. Use Yahoo finance library and plot a graphic of 1 year of price history")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Fetch the NVIDIA stock price. Use Yahoo finance library and plot a graphic of 1 year of price history           │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-2.0-flash-exp ────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import yfinance as yf
#   import matplotlib.pyplot as plt
#
#   # Define the ticker symbol for NVIDIA
#   ticker_symbol = "NVDA"
#
#   # Get data for the past year
#   data = yf.download(ticker_symbol, period="1y")
#
#   # Plot the closing prices
#   plt.figure(figsize=(12, 6))
#   plt.plot(data['Close'], label='NVDA Closing Price')
#   plt.title('NVIDIA (NVDA) Stock Price - 1 Year')
#   plt.xlabel('Date')
#   plt.ylabel('Price (USD)')
#   plt.legend()
#   plt.grid(True)
#   plt.show()
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [*********************100%***********************]  1 of 1 completed
# Out: None
# [Step 0: Duration 6.21 seconds| Input tokens: 2,202 | Output tokens: 171]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("The plot of NVIDIA stock price for the past year has been displayed.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: The plot of NVIDIA stock price for the past year has been displayed.
# [Step 1: Duration 1.20 seconds| Input tokens: 4,796 | Output tokens: 238]
# 'The plot of NVIDIA stock price for the past year has been displayed.'
